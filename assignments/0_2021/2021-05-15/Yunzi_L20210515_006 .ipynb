# %% [markdown]
# # Lecture 3：一共有多少袋大米？

# %% [markdown]
# - **Name (姓名)**: Ye Yunzi
# - **Date (日期)**: 05/22/2021
#
#
# - **Score (成绩)**:[Provided by Teacher]
# - **Comment By Teacher (评语)**: A+
# 很好，特别是用了自己身边的例子举一反三。联系最后一题条件判断写得不是很符合题意，虽然结果是正确的。考虑把

# %% [markdown]
# ## Problem
# 在古代，由于科学技术水平并不是很发达，人们并不是总能吃饱，因而像米面这样的食物就显得很珍贵，经常会被用来作为礼物赠送或奖赏给关系亲密的人。有这样一位生活在古代的国王，他准备给他手下一位非常得力的将军2000袋大米作为奖赏，可是他并不打算将这2000袋大米一次全部赏给这位将军，而是在第1天奖赏1袋大米，第2天奖赏2袋，第3天奖赏3袋，也就是每一天都在前一天奖赏的大米袋数上增加1袋，这样连续每天奖赏直到国王自己手中剩下的大米不够下一次对将军的奖赏为止。现在请你算一算，按照国王这样的奖赏办法，2000袋的奖赏大米足够连续奖赏这位将军多少天？在最后一天国王手中剩下的大米不够当天的奖赏时，国王手中剩下多少袋大米？

# %% [markdown]
# ## Objective 学习目标
#
# - 学习`while`引导的循环语句，理解循环语句语法构成、循环体以及退出循环的条件判断等
# - 使用`>=`,`<=`进行“不少于”、“不多于”等比较
# - 体验循环语句对编写不重复代码的帮助
# - 理解掌握变量自增、自减代码的完整和简便写法（例如：`a = a + 1` 和 `a += 1`)
# - 思考如何管理大量的一组同类性质的数据
# - 字符串中`\n`,`\t`,`\r`的意义
# - 开始尝试理解程序的bug，错误和bug的区别。

# %% [markdown]
# ## Math
#
# - 数列的概念
# - 数的大小比较
# - 寻找解决实际问题中不变的量

# %% [markdown]
# ## Python

# %%
# How do you solve this problem if using arithmetic calculation instead of programming
# 思考如果不使用用编程，而使用传统算术的方法来求解这个问题，你会怎么做？

# %%
# Solution 0
rice_in_king_initial = 2000
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 1, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded = days_awarded + 1
    rice_to_general = rice_to_general + 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  62 , rice left in king: 47 , total rice in general:  1953

# %%
# Another solution with detailed explanation and output
# 另一个有详细解释和输出的实现方案

# declare and initiate some variables before calculating
# 在正式计算模拟前声明一些变量，并给这些变量一些初始的数值

# rice that King has at the very begining
# 国王一开始打算奖赏的大米总袋数 2000
rice_in_king_initial = 2016
# rice that King has for awarding 
# 国王手中拥有的用来奖赏的大米
rice_in_king = rice_in_king_initial

# rice that General awarded from King 
# 将军手中所有的奖赏大米
rice_in_general = 0

# rice that will awarded to General in some day，set to 0 in the begining
# 某一天里，将军从国王那里获得的大米代数，一开始设为1
rice_to_general = 1       

# days already awarded, set to 0 in the begining
# 已经奖赏的天数，一开始没有奖赏，设为0天
days_awarded = 0

# No. of current day
# 当前是第几天
cur_day = 1

# while rice in King is more than the rice that will be awarded to General
# 当国王手中（剩余）的大米足够下一次发给将军时
while rice_in_king >= rice_to_general:
    print("\n今天是第", cur_day, "天")
    print("  国王有大米:", rice_in_king, "袋，需要奖赏给将军: ", rice_to_general, "袋")
    print("  国王大米足够，开始奖赏:")
    rice_in_king = rice_in_king - rice_to_general
    rice_in_general = rice_in_general + rice_to_general
    days_awarded = days_awarded + 1
    print("  今天的奖赏已经完成，奖赏了", rice_to_general, "袋大米")
    print("  国王还剩下", rice_in_king, "袋大米")
    print("  将军目前共有:", rice_in_general,"袋大米")
    print("  到今天为止，一共连续奖赏了", days_awarded, "天")
    # prepare rice awarded to general for next day
    rice_to_general_next_day = rice_to_general + 1
    print("  明天的奖赏将会是", rice_to_general_next_day,"袋大米")
    
    # here comes the next day 第二天来了
    cur_day = cur_day + 1
    
    # update rice_to_general for compare with rice_in_king
    # 更新这一天要奖赏给将军的大米袋数
    rice_to_general = rice_to_general_next_day

# when program are executed here, it means king's rice is not enough for
# nex day's awarding.
# 当程序运行到此处时，说明国王的大米已经不够第二天的奖赏了
print("\n今天是第", cur_day, "天，国王的大米不够了，奖赏停止。") 
print("  国王还剩下", rice_in_king, "袋大米")
print("  今天原本需要奖赏将军", rice_to_general, "袋大米")
print("  国王一共奖赏给了将军", rice_in_general, "袋大米")
# Out:
# 今天是第 1 天
#   国王有大米: 2016 袋，需要奖赏给将军:  1 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 1 袋大米
#   国王还剩下 2015 袋大米
#   将军目前共有: 1 袋大米
#   到今天为止，一共连续奖赏了 1 天
#   明天的奖赏将会是 2 袋大米
#
# 今天是第 2 天
#   国王有大米: 2015 袋，需要奖赏给将军:  2 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 2 袋大米
#   国王还剩下 2013 袋大米
#   将军目前共有: 3 袋大米
#   到今天为止，一共连续奖赏了 2 天
#   明天的奖赏将会是 3 袋大米
#
# 今天是第 3 天
#   国王有大米: 2013 袋，需要奖赏给将军:  3 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 3 袋大米
#   国王还剩下 2010 袋大米
#   将军目前共有: 6 袋大米
#   到今天为止，一共连续奖赏了 3 天
#   明天的奖赏将会是 4 袋大米
#
# 今天是第 4 天
#   国王有大米: 2010 袋，需要奖赏给将军:  4 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 4 袋大米
#   国王还剩下 2006 袋大米
#   将军目前共有: 10 袋大米
#   到今天为止，一共连续奖赏了 4 天
#   明天的奖赏将会是 5 袋大米
#
# 今天是第 5 天
#   国王有大米: 2006 袋，需要奖赏给将军:  5 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 5 袋大米
#   国王还剩下 2001 袋大米
#   将军目前共有: 15 袋大米
#   到今天为止，一共连续奖赏了 5 天
#   明天的奖赏将会是 6 袋大米
#
# 今天是第 6 天
#   国王有大米: 2001 袋，需要奖赏给将军:  6 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 6 袋大米
#   国王还剩下 1995 袋大米
#   将军目前共有: 21 袋大米
#   到今天为止，一共连续奖赏了 6 天
#   明天的奖赏将会是 7 袋大米
#
# 今天是第 7 天
#   国王有大米: 1995 袋，需要奖赏给将军:  7 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 7 袋大米
#   国王还剩下 1988 袋大米
#   将军目前共有: 28 袋大米
#   到今天为止，一共连续奖赏了 7 天
#   明天的奖赏将会是 8 袋大米
#
# 今天是第 8 天
#   国王有大米: 1988 袋，需要奖赏给将军:  8 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 8 袋大米
#   国王还剩下 1980 袋大米
#   将军目前共有: 36 袋大米
#   到今天为止，一共连续奖赏了 8 天
#   明天的奖赏将会是 9 袋大米
#
# 今天是第 9 天
#   国王有大米: 1980 袋，需要奖赏给将军:  9 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 9 袋大米
#   国王还剩下 1971 袋大米
#   将军目前共有: 45 袋大米
#   到今天为止，一共连续奖赏了 9 天
#   明天的奖赏将会是 10 袋大米
#
# 今天是第 10 天
#   国王有大米: 1971 袋，需要奖赏给将军:  10 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 10 袋大米
#   国王还剩下 1961 袋大米
#   将军目前共有: 55 袋大米
#   到今天为止，一共连续奖赏了 10 天
#   明天的奖赏将会是 11 袋大米
#
# 今天是第 11 天
#   国王有大米: 1961 袋，需要奖赏给将军:  11 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 11 袋大米
#   国王还剩下 1950 袋大米
#   将军目前共有: 66 袋大米
#   到今天为止，一共连续奖赏了 11 天
#   明天的奖赏将会是 12 袋大米
#
# 今天是第 12 天
#   国王有大米: 1950 袋，需要奖赏给将军:  12 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 12 袋大米
#   国王还剩下 1938 袋大米
#   将军目前共有: 78 袋大米
#   到今天为止，一共连续奖赏了 12 天
#   明天的奖赏将会是 13 袋大米
#
# 今天是第 13 天
#   国王有大米: 1938 袋，需要奖赏给将军:  13 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 13 袋大米
#   国王还剩下 1925 袋大米
#   将军目前共有: 91 袋大米
#   到今天为止，一共连续奖赏了 13 天
#   明天的奖赏将会是 14 袋大米
#
# 今天是第 14 天
#   国王有大米: 1925 袋，需要奖赏给将军:  14 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 14 袋大米
#   国王还剩下 1911 袋大米
#   将军目前共有: 105 袋大米
#   到今天为止，一共连续奖赏了 14 天
#   明天的奖赏将会是 15 袋大米
#
# 今天是第 15 天
#   国王有大米: 1911 袋，需要奖赏给将军:  15 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 15 袋大米
#   国王还剩下 1896 袋大米
#   将军目前共有: 120 袋大米
#   到今天为止，一共连续奖赏了 15 天
#   明天的奖赏将会是 16 袋大米
#
# 今天是第 16 天
#   国王有大米: 1896 袋，需要奖赏给将军:  16 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 16 袋大米
#   国王还剩下 1880 袋大米
#   将军目前共有: 136 袋大米
#   到今天为止，一共连续奖赏了 16 天
#   明天的奖赏将会是 17 袋大米
#
# 今天是第 17 天
#   国王有大米: 1880 袋，需要奖赏给将军:  17 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 17 袋大米
#   国王还剩下 1863 袋大米
#   将军目前共有: 153 袋大米
#   到今天为止，一共连续奖赏了 17 天
#   明天的奖赏将会是 18 袋大米
#
# 今天是第 18 天
#   国王有大米: 1863 袋，需要奖赏给将军:  18 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 18 袋大米
#   国王还剩下 1845 袋大米
#   将军目前共有: 171 袋大米
#   到今天为止，一共连续奖赏了 18 天
#   明天的奖赏将会是 19 袋大米
#
# 今天是第 19 天
#   国王有大米: 1845 袋，需要奖赏给将军:  19 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 19 袋大米
#   国王还剩下 1826 袋大米
#   将军目前共有: 190 袋大米
#   到今天为止，一共连续奖赏了 19 天
#   明天的奖赏将会是 20 袋大米
#
# 今天是第 20 天
#   国王有大米: 1826 袋，需要奖赏给将军:  20 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 20 袋大米
#   国王还剩下 1806 袋大米
#   将军目前共有: 210 袋大米
#   到今天为止，一共连续奖赏了 20 天
#   明天的奖赏将会是 21 袋大米
#
# 今天是第 21 天
#   国王有大米: 1806 袋，需要奖赏给将军:  21 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 21 袋大米
#   国王还剩下 1785 袋大米
#   将军目前共有: 231 袋大米
#   到今天为止，一共连续奖赏了 21 天
#   明天的奖赏将会是 22 袋大米
#
# 今天是第 22 天
#   国王有大米: 1785 袋，需要奖赏给将军:  22 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 22 袋大米
#   国王还剩下 1763 袋大米
#   将军目前共有: 253 袋大米
#   到今天为止，一共连续奖赏了 22 天
#   明天的奖赏将会是 23 袋大米
#
# 今天是第 23 天
#   国王有大米: 1763 袋，需要奖赏给将军:  23 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 23 袋大米
#   国王还剩下 1740 袋大米
#   将军目前共有: 276 袋大米
#   到今天为止，一共连续奖赏了 23 天
#   明天的奖赏将会是 24 袋大米
#
# 今天是第 24 天
#   国王有大米: 1740 袋，需要奖赏给将军:  24 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 24 袋大米
#   国王还剩下 1716 袋大米
#   将军目前共有: 300 袋大米
#   到今天为止，一共连续奖赏了 24 天
#   明天的奖赏将会是 25 袋大米
#
# 今天是第 25 天
#   国王有大米: 1716 袋，需要奖赏给将军:  25 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 25 袋大米
#   国王还剩下 1691 袋大米
#   将军目前共有: 325 袋大米
#   到今天为止，一共连续奖赏了 25 天
#   明天的奖赏将会是 26 袋大米
#
# 今天是第 26 天
#   国王有大米: 1691 袋，需要奖赏给将军:  26 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 26 袋大米
#   国王还剩下 1665 袋大米
#   将军目前共有: 351 袋大米
#   到今天为止，一共连续奖赏了 26 天
#   明天的奖赏将会是 27 袋大米
#
# 今天是第 27 天
#   国王有大米: 1665 袋，需要奖赏给将军:  27 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 27 袋大米
#   国王还剩下 1638 袋大米
#   将军目前共有: 378 袋大米
#   到今天为止，一共连续奖赏了 27 天
#   明天的奖赏将会是 28 袋大米
#
# 今天是第 28 天
#   国王有大米: 1638 袋，需要奖赏给将军:  28 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 28 袋大米
#   国王还剩下 1610 袋大米
#   将军目前共有: 406 袋大米
#   到今天为止，一共连续奖赏了 28 天
#   明天的奖赏将会是 29 袋大米
#
# 今天是第 29 天
#   国王有大米: 1610 袋，需要奖赏给将军:  29 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 29 袋大米
#   国王还剩下 1581 袋大米
#   将军目前共有: 435 袋大米
#   到今天为止，一共连续奖赏了 29 天
#   明天的奖赏将会是 30 袋大米
#
# 今天是第 30 天
#   国王有大米: 1581 袋，需要奖赏给将军:  30 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 30 袋大米
#   国王还剩下 1551 袋大米
#   将军目前共有: 465 袋大米
#   到今天为止，一共连续奖赏了 30 天
#   明天的奖赏将会是 31 袋大米
#
# 今天是第 31 天
#   国王有大米: 1551 袋，需要奖赏给将军:  31 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 31 袋大米
#   国王还剩下 1520 袋大米
#   将军目前共有: 496 袋大米
#   到今天为止，一共连续奖赏了 31 天
#   明天的奖赏将会是 32 袋大米
#
# 今天是第 32 天
#   国王有大米: 1520 袋，需要奖赏给将军:  32 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 32 袋大米
#   国王还剩下 1488 袋大米
#   将军目前共有: 528 袋大米
#   到今天为止，一共连续奖赏了 32 天
#   明天的奖赏将会是 33 袋大米
#
# 今天是第 33 天
#   国王有大米: 1488 袋，需要奖赏给将军:  33 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 33 袋大米
#   国王还剩下 1455 袋大米
#   将军目前共有: 561 袋大米
#   到今天为止，一共连续奖赏了 33 天
#   明天的奖赏将会是 34 袋大米
#
# 今天是第 34 天
#   国王有大米: 1455 袋，需要奖赏给将军:  34 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 34 袋大米
#   国王还剩下 1421 袋大米
#   将军目前共有: 595 袋大米
#   到今天为止，一共连续奖赏了 34 天
#   明天的奖赏将会是 35 袋大米
#
# 今天是第 35 天
#   国王有大米: 1421 袋，需要奖赏给将军:  35 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 35 袋大米
#   国王还剩下 1386 袋大米
#   将军目前共有: 630 袋大米
#   到今天为止，一共连续奖赏了 35 天
#   明天的奖赏将会是 36 袋大米
#
# 今天是第 36 天
#   国王有大米: 1386 袋，需要奖赏给将军:  36 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 36 袋大米
#   国王还剩下 1350 袋大米
#   将军目前共有: 666 袋大米
#   到今天为止，一共连续奖赏了 36 天
#   明天的奖赏将会是 37 袋大米
#
# 今天是第 37 天
#   国王有大米: 1350 袋，需要奖赏给将军:  37 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 37 袋大米
#   国王还剩下 1313 袋大米
#   将军目前共有: 703 袋大米
#   到今天为止，一共连续奖赏了 37 天
#   明天的奖赏将会是 38 袋大米
#
# 今天是第 38 天
#   国王有大米: 1313 袋，需要奖赏给将军:  38 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 38 袋大米
#   国王还剩下 1275 袋大米
#   将军目前共有: 741 袋大米
#   到今天为止，一共连续奖赏了 38 天
#   明天的奖赏将会是 39 袋大米
#
# 今天是第 39 天
#   国王有大米: 1275 袋，需要奖赏给将军:  39 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 39 袋大米
#   国王还剩下 1236 袋大米
#   将军目前共有: 780 袋大米
#   到今天为止，一共连续奖赏了 39 天
#   明天的奖赏将会是 40 袋大米
#
# 今天是第 40 天
#   国王有大米: 1236 袋，需要奖赏给将军:  40 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 40 袋大米
#   国王还剩下 1196 袋大米
#   将军目前共有: 820 袋大米
#   到今天为止，一共连续奖赏了 40 天
#   明天的奖赏将会是 41 袋大米
#
# 今天是第 41 天
#   国王有大米: 1196 袋，需要奖赏给将军:  41 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 41 袋大米
#   国王还剩下 1155 袋大米
#   将军目前共有: 861 袋大米
#   到今天为止，一共连续奖赏了 41 天
#   明天的奖赏将会是 42 袋大米
#
# 今天是第 42 天
#   国王有大米: 1155 袋，需要奖赏给将军:  42 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 42 袋大米
#   国王还剩下 1113 袋大米
#   将军目前共有: 903 袋大米
#   到今天为止，一共连续奖赏了 42 天
#   明天的奖赏将会是 43 袋大米
#
# 今天是第 43 天
#   国王有大米: 1113 袋，需要奖赏给将军:  43 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 43 袋大米
#   国王还剩下 1070 袋大米
#   将军目前共有: 946 袋大米
#   到今天为止，一共连续奖赏了 43 天
#   明天的奖赏将会是 44 袋大米
#
# 今天是第 44 天
#   国王有大米: 1070 袋，需要奖赏给将军:  44 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 44 袋大米
#   国王还剩下 1026 袋大米
#   将军目前共有: 990 袋大米
#   到今天为止，一共连续奖赏了 44 天
#   明天的奖赏将会是 45 袋大米
#
# 今天是第 45 天
#   国王有大米: 1026 袋，需要奖赏给将军:  45 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 45 袋大米
#   国王还剩下 981 袋大米
#   将军目前共有: 1035 袋大米
#   到今天为止，一共连续奖赏了 45 天
#   明天的奖赏将会是 46 袋大米
#
# 今天是第 46 天
#   国王有大米: 981 袋，需要奖赏给将军:  46 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 46 袋大米
#   国王还剩下 935 袋大米
#   将军目前共有: 1081 袋大米
#   到今天为止，一共连续奖赏了 46 天
#   明天的奖赏将会是 47 袋大米
#
# 今天是第 47 天
#   国王有大米: 935 袋，需要奖赏给将军:  47 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 47 袋大米
#   国王还剩下 888 袋大米
#   将军目前共有: 1128 袋大米
#   到今天为止，一共连续奖赏了 47 天
#   明天的奖赏将会是 48 袋大米
#
# 今天是第 48 天
#   国王有大米: 888 袋，需要奖赏给将军:  48 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 48 袋大米
#   国王还剩下 840 袋大米
#   将军目前共有: 1176 袋大米
#   到今天为止，一共连续奖赏了 48 天
#   明天的奖赏将会是 49 袋大米
#
# 今天是第 49 天
#   国王有大米: 840 袋，需要奖赏给将军:  49 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 49 袋大米
#   国王还剩下 791 袋大米
#   将军目前共有: 1225 袋大米
#   到今天为止，一共连续奖赏了 49 天
#   明天的奖赏将会是 50 袋大米
#
# 今天是第 50 天
#   国王有大米: 791 袋，需要奖赏给将军:  50 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 50 袋大米
#   国王还剩下 741 袋大米
#   将军目前共有: 1275 袋大米
#   到今天为止，一共连续奖赏了 50 天
#   明天的奖赏将会是 51 袋大米
#
# 今天是第 51 天
#   国王有大米: 741 袋，需要奖赏给将军:  51 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 51 袋大米
#   国王还剩下 690 袋大米
#   将军目前共有: 1326 袋大米
#   到今天为止，一共连续奖赏了 51 天
#   明天的奖赏将会是 52 袋大米
#
# 今天是第 52 天
#   国王有大米: 690 袋，需要奖赏给将军:  52 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 52 袋大米
#   国王还剩下 638 袋大米
#   将军目前共有: 1378 袋大米
#   到今天为止，一共连续奖赏了 52 天
#   明天的奖赏将会是 53 袋大米
#
# 今天是第 53 天
#   国王有大米: 638 袋，需要奖赏给将军:  53 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 53 袋大米
#   国王还剩下 585 袋大米
#   将军目前共有: 1431 袋大米
#   到今天为止，一共连续奖赏了 53 天
#   明天的奖赏将会是 54 袋大米
#
# 今天是第 54 天
#   国王有大米: 585 袋，需要奖赏给将军:  54 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 54 袋大米
#   国王还剩下 531 袋大米
#   将军目前共有: 1485 袋大米
#   到今天为止，一共连续奖赏了 54 天
#   明天的奖赏将会是 55 袋大米
#
# 今天是第 55 天
#   国王有大米: 531 袋，需要奖赏给将军:  55 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 55 袋大米
#   国王还剩下 476 袋大米
#   将军目前共有: 1540 袋大米
#   到今天为止，一共连续奖赏了 55 天
#   明天的奖赏将会是 56 袋大米
#
# 今天是第 56 天
#   国王有大米: 476 袋，需要奖赏给将军:  56 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 56 袋大米
#   国王还剩下 420 袋大米
#   将军目前共有: 1596 袋大米
#   到今天为止，一共连续奖赏了 56 天
#   明天的奖赏将会是 57 袋大米
#
# 今天是第 57 天
#   国王有大米: 420 袋，需要奖赏给将军:  57 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 57 袋大米
#   国王还剩下 363 袋大米
#   将军目前共有: 1653 袋大米
#   到今天为止，一共连续奖赏了 57 天
#   明天的奖赏将会是 58 袋大米
#
# 今天是第 58 天
#   国王有大米: 363 袋，需要奖赏给将军:  58 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 58 袋大米
#   国王还剩下 305 袋大米
#   将军目前共有: 1711 袋大米
#   到今天为止，一共连续奖赏了 58 天
#   明天的奖赏将会是 59 袋大米
#
# 今天是第 59 天
#   国王有大米: 305 袋，需要奖赏给将军:  59 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 59 袋大米
#   国王还剩下 246 袋大米
#   将军目前共有: 1770 袋大米
#   到今天为止，一共连续奖赏了 59 天
#   明天的奖赏将会是 60 袋大米
#
# 今天是第 60 天
#   国王有大米: 246 袋，需要奖赏给将军:  60 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 60 袋大米
#   国王还剩下 186 袋大米
#   将军目前共有: 1830 袋大米
#   到今天为止，一共连续奖赏了 60 天
#   明天的奖赏将会是 61 袋大米
#
# 今天是第 61 天
#   国王有大米: 186 袋，需要奖赏给将军:  61 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 61 袋大米
#   国王还剩下 125 袋大米
#   将军目前共有: 1891 袋大米
#   到今天为止，一共连续奖赏了 61 天
#   明天的奖赏将会是 62 袋大米
#
# 今天是第 62 天
#   国王有大米: 125 袋，需要奖赏给将军:  62 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 62 袋大米
#   国王还剩下 63 袋大米
#   将军目前共有: 1953 袋大米
#   到今天为止，一共连续奖赏了 62 天
#   明天的奖赏将会是 63 袋大米
#
# 今天是第 63 天
#   国王有大米: 63 袋，需要奖赏给将军:  63 袋
#   国王大米足够，开始奖赏:
#   今天的奖赏已经完成，奖赏了 63 袋大米
#   国王还剩下 0 袋大米
#   将军目前共有: 2016 袋大米
#   到今天为止，一共连续奖赏了 63 天
#   明天的奖赏将会是 64 袋大米
#
# 今天是第 64 天，国王的大米不够了，奖赏停止。
#   国王还剩下 0 袋大米
#   今天原本需要奖赏将军 64 袋大米
#   国王一共奖赏给了将军 2016 袋大米

# %%
RMB_in_Dad_initial = 2000

RMB_in_Dad = RMB_in_Dad_initial

RMB_wasted_by_Yunlei = 0

RMB_to_Yunlei = 1       

days_payed = 0

cur_day = 1

while RMB_in_Dad >= RMB_to_Yunlei:
    print("\n今天是第", cur_day, "天")
    print("  爸爸手上有:", RMB_in_Dad, "元，云耒索要: ", RMB_to_Yunlei, "元")
    print("  爸爸有钱给，那就给吧:")
    RMB_in_Dad = RMB_in_Dad - RMB_to_Yunlei
    RMB_wasted_by_Yunlei = RMB_wasted_by_Yunlei + RMB_to_Yunlei
    days_payed = days_payed + 1
    print("  今天给了", RMB_to_Yunlei, "元")
    print("  还剩下", RMB_in_Dad, "元")
    print("  云耒挥霍了:", RMB_wasted_by_Yunlei,"元")
    print("  到今天为止，连续一共给了云耒", days_payed, "天")
    RMB_to_Yunlei_next_day = RMB_to_Yunlei * 2
    print("  明天要给云耒", RMB_to_Yunlei_next_day,"元")
    
    cur_day = cur_day + 1
    
    RMB_to_Yunlei = RMB_to_Yunlei_next_day
        
print("\n今天是第", cur_day, "天，爸爸钱不够了，给不起了，不能再给了。") 
print("  爸爸只剩下", RMB_in_Dad, "元")
print("  今天云耒原本还想要", RMB_to_Yunlei, "元")
print("  这家伙已经挥霍了", RMB_wasted_by_Yunlei, "元")
# Out:
# 今天是第 1 天
#   爸爸手上有: 2000 元，云耒索要:  1 元
#   爸爸有钱给，那就给吧:
#   今天给了 1 元
#   还剩下 1999 元
#   云耒挥霍了: 1 元
#   到今天为止，连续一共给了云耒 1 天
#   明天要给云耒 2 元
#
# 今天是第 2 天
#   爸爸手上有: 1999 元，云耒索要:  2 元
#   爸爸有钱给，那就给吧:
#   今天给了 2 元
#   还剩下 1997 元
#   云耒挥霍了: 3 元
#   到今天为止，连续一共给了云耒 2 天
#   明天要给云耒 4 元
#
# 今天是第 3 天
#   爸爸手上有: 1997 元，云耒索要:  4 元
#   爸爸有钱给，那就给吧:
#   今天给了 4 元
#   还剩下 1993 元
#   云耒挥霍了: 7 元
#   到今天为止，连续一共给了云耒 3 天
#   明天要给云耒 8 元
#
# 今天是第 4 天
#   爸爸手上有: 1993 元，云耒索要:  8 元
#   爸爸有钱给，那就给吧:
#   今天给了 8 元
#   还剩下 1985 元
#   云耒挥霍了: 15 元
#   到今天为止，连续一共给了云耒 4 天
#   明天要给云耒 16 元
#
# 今天是第 5 天
#   爸爸手上有: 1985 元，云耒索要:  16 元
#   爸爸有钱给，那就给吧:
#   今天给了 16 元
#   还剩下 1969 元
#   云耒挥霍了: 31 元
#   到今天为止，连续一共给了云耒 5 天
#   明天要给云耒 32 元
#
# 今天是第 6 天
#   爸爸手上有: 1969 元，云耒索要:  32 元
#   爸爸有钱给，那就给吧:
#   今天给了 32 元
#   还剩下 1937 元
#   云耒挥霍了: 63 元
#   到今天为止，连续一共给了云耒 6 天
#   明天要给云耒 64 元
#
# 今天是第 7 天
#   爸爸手上有: 1937 元，云耒索要:  64 元
#   爸爸有钱给，那就给吧:
#   今天给了 64 元
#   还剩下 1873 元
#   云耒挥霍了: 127 元
#   到今天为止，连续一共给了云耒 7 天
#   明天要给云耒 128 元
#
# 今天是第 8 天
#   爸爸手上有: 1873 元，云耒索要:  128 元
#   爸爸有钱给，那就给吧:
#   今天给了 128 元
#   还剩下 1745 元
#   云耒挥霍了: 255 元
#   到今天为止，连续一共给了云耒 8 天
#   明天要给云耒 256 元
#
# 今天是第 9 天
#   爸爸手上有: 1745 元，云耒索要:  256 元
#   爸爸有钱给，那就给吧:
#   今天给了 256 元
#   还剩下 1489 元
#   云耒挥霍了: 511 元
#   到今天为止，连续一共给了云耒 9 天
#   明天要给云耒 512 元
#
# 今天是第 10 天
#   爸爸手上有: 1489 元，云耒索要:  512 元
#   爸爸有钱给，那就给吧:
#   今天给了 512 元
#   还剩下 977 元
#   云耒挥霍了: 1023 元
#   到今天为止，连续一共给了云耒 10 天
#   明天要给云耒 1024 元
#
# 今天是第 11 天，爸爸钱不够了，给不起了，不能再给了。
#   爸爸只剩下 977 元
#   今天云耒原本还想要 1024 元
#   这家伙已经挥霍了 1023 元

# %%
print('Sophie\ns name is \rYefei\tadsfafd')
# Out:
# Sophie
# Yefei	adsfafd

# %%
# correction 纠正
# number of parameters in method 'print' can be infinite, not 1.
# print方法可以接受的数据个数可以是无限多个，不是1个.
print(123, 1244, 567, 1234)
# Out:
# 123 1244 567 1234

# %%
# \t         \r
print("Luchuannnnn\r Yunzi       ")
# Out:
#  Yunzi

# %%
print(Jason)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2b72bd52416b> in <module>
# ----> 1 print(Jason)
#
# NameError: name 'Jason' is not defined

# %%
# review randint, find bugs in the follow codes
# 复习randint, 寻找下面代码中的bug
from random import randint
num = randint(1, 10)
n_tries = 1
while num < 10:
    print(n_tries, "try, num generated is", num)
    num = randint(1, 10)
    n_tries = n_tries + 1
    
print("tried randint(1, 10)", n_tries, "times \nbefore we got 10")
# Out:
# 1 try, num generated is 9
# 2 try, num generated is 5
# 3 try, num generated is 9
# 4 try, num generated is 4
# 5 try, num generated is 6
# 6 try, num generated is 5
# tried randint(1, 10) 7 times
# before we got 10

# %%
a = 10
a = a + 1
print("a =", a)

a = 10
a += 1
print("a =", a)
# Out:
# a = 11
# a = 11

# %%
a = 10
a += 2
print(a, type(a))
a -= 2
print(a, type(a))
a *= 2
print(a, type(a))
a /= 2
print(a, type(a))
# Out:
# 12 <class 'int'>
# 10 <class 'int'>
# 20 <class 'int'>
# 10.0 <class 'float'>

# %%
rice_in_generals = [0, 1, 3, 6, 10, 15, 21]

# %% [markdown]
# ## Did you know?
# 现代计算机编程语言有很多种，每一种现代计算机语言都有自己的语法来表示条件和循环控制。此外，在Python语言中，`while`引导的循环语句只是实现循环的形式之一。

# %% [markdown]
# ## Exercise

# %% [markdown]
# 1. 通常一个问题会有不止一种编程方案来求解，像本节的国王问题，本题下的代码单元格里提供了包括原始解法在内的一共3不同的编程写法，其中另外2种写法在国王打算奖赏的大米数量为2000的时候都也得到正确的答案，但是其中的一种方法当国王大米数量不是2000的时候有可能会得到错误的结果。试着将国王一开始拟奖赏的大米总数从2000修改为2016，分别运行本讲示例中的解法以及本练习题额外提供的两种解法，观察三种解法给出的结果有什么不同，指出本题提供的哪一种解法是错误的。尝试着去解释为什么会出现这样的错误。
#
#    把你的答案写在这里：
#    - 第（二）种额外解决方案是错误的；
#    - 当国王一开始的大米总数变为2016时，它给出的答案是：（62），与另外两种方法得到的结果不一样；
#    - 出现这种错误的原因是：没有考虑到“while rice_in_king = rice_to_general”的情形。

# %%
# try to change the value to 2000 and 2016
# 尝试修改变量 rice_in_king_initial 值分别为2000， 2016
rice_in_king_initial = 2016

# %%
# Solution 0 (Original for the lecture)
# 第零种解决方案（原始解决方案）
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 1, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general += 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  63 , rice left in king: 0 , total rice in general:  2016

# %%
# Extra Solution 1
# 第一种额外解决方案
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 0, 0
while rice_in_king > rice_to_general:
    rice_to_general += 1
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1

print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  63 , rice left in king: 0 , total rice in general:  2016

# %%
# Extra Solution 2
# 第二种额外解决方案
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 1, 0
while rice_in_king > rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general += 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  62 , rice left in king: 63 , total rice in general:  1953

# %% [markdown]
# 2. 如果在本讲的大米奖赏问题中，把国王第一天对将军的奖赏从1袋大米增加为10袋大米，以后每过一天仍然在前一天的基础上多奖赏一袋，那么2000袋大米可以奖赏多少天，国王手中是否有剩余的大米？如果国王一开始的大米为2016袋结果又是怎样呢？请在下面的代码单元格中修改原始的代码后，求解该问题。并将答案写本单元格相应的位置。
#
#    提示：你只需要修改一行代码即可
#
#    把你的结果写在这里：
#    - 国王一开始有2000袋大米，可连续奖赏（54）天，国王剩余（29）袋；
#    - 国王一开始有2016袋大米，可连续奖赏（54）天，国王剩余（45）袋。

# %%
rice_in_king_initial = 2000
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 10, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general += 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  54 , rice left in king: 29 , total rice in general:  1971

# %%
rice_in_king_initial = 2016
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 10, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general += 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  54 , rice left in king: 45 , total rice in general:  1971

# %% [markdown]
# 3. 继续以本讲示例的大米问题为背景，如果把国王对将军的奖赏从每天增加1袋大米到每天增加10袋大米，保持第一天的奖赏为1袋大米不变。那么2000袋大米可以奖赏多少天？国王手中是否有剩余的大米？如果国王一开始的大米为2016袋结果又是怎样呢？请在下面的代码单元格中修改现成的代码后，求解该问题。
#
#    提示：你只需要修改一行代码即可
#
#    把你的结果写在这里：
#    - 国王一开始有2000袋大米，可连续奖赏（62）天，国王剩余（47）袋；
#    - 国王一开始有2016袋大米，可连续奖赏（63）天，国王剩余（0）袋。

# %%
rice_in_king_initial = 2016
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 1, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general += 1
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  63 , rice left in king: 0 , total rice in general:  2016

# %% [markdown]
# 4. 继续以本讲示例的大米问题为背景，如果把国王对将军的奖赏改为：第一天奖赏1袋，第2天奖赏2袋，第三天奖赏4袋，第4天奖赏8袋，...。也就是每一天的奖赏都是前一天奖赏的2倍。那么2000袋大米可以奖赏多少天？国王手中是否有剩余的大米？如果国王一开始的大米为2016袋结果又是怎样呢？请在下面的代码单元格中修改现成的代码后，求解该问题。
#
#    提示：你只需要修改一行代码即可
#
#    把你的结果写在这里：
#    - 国王一开始有2000袋大米，可连续奖赏（10）天，国王剩余（977）袋；
#    - 国王一开始有2016袋大米，可连续奖赏（10）天，国王剩余（993）袋。

# %%
rice_in_king_initial = 2016
rice_in_king = rice_in_king_initial
rice_in_general, rice_to_general, days_awarded = 0, 1, 0
while rice_in_king >= rice_to_general:
    rice_in_king -= rice_to_general
    rice_in_general += rice_to_general
    days_awarded += 1
    rice_to_general *= 2
    
print("days awarded: ", days_awarded, 
      ", rice left in king:", rice_in_king, 
      ", total rice in general: ", rice_in_general)
# Out:
# days awarded:  10 , rice left in king: 993 , total rice in general:  1023

# %% [markdown]
# 5. 自己动手编写一段包括`while`循环语句的程序，计算打印出从1开始到100所有100个连续的自然数的和。你的程序应该返回的正确数值是5050。如果让你求解1-100这100个自然数内所有奇数或偶数的和，你的程序应该做怎样的修改？最后的答案分别是什么？

# %%
sum_n, num_n = 1, 1
while num_n < 100 :
    num_n += 1
    sum_n += num_n 
    
print("总和是：", sum_n)
# Out:
# 总和是： 5050

# %%
# sum_odd
num_initial = 1
num_n = num_initial
sum_n, num_n = 1, 1
while num_n <= 97 :           # 为什么这里是97？有凑数字嫌疑，考虑把它设为<=100
    num_n += 2
    sum_n += num_n
    
print("奇数总和是：", sum_n)
# Out:
# 奇数总和是： 2500

# %%
# sum_even
num_initial = 2
num_n = num_initial
sum_n, num_n = 2, 2
while num_n <= 98:  # 为什么这里是98？有凑数字嫌疑，考虑把它设为<=100
    num_n += 2
    sum_n += num_n
    
print("偶数总和是：", sum_n)
# Out:
# 偶数总和是： 2550
