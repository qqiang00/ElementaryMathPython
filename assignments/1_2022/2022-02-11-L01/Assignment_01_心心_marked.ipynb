# %% [markdown]
# 95/100
#  marked by Sophie/菲菲, Qiang

# %%
#1a
print("I love China and Canada.")
# Out:
# I love China and Canada.

# %%
#1b
print("I like Python programming language, and I like Math too.")
# Out:
# I like Python programming language, and I like Math too.

# %%
#1c
print("Our teacher’s name is Qiang.")
# Out:
# Our teacher’s name is Qiang.

# %%
#1d
print("“CN” is the abbreviation of China.")
# Out:
# “CN” is the abbreviation of China.

# %%
#1e
print("The abbreviation of Canda is “CAD”.")
# Out:
# The abbreviation of Canda is “CAD”.

# %%
#1f
print("中国的首都是’北京’。")
# Out:
# 中国的首都是’北京’。

# %%
#2a
sum = 0
for i in range(1, 20, 2):
    sum += i
print(sum)
# Out:
# 100

# %%
#2b.1
sum1 = 0
for i in range(2, 11, 2):
    sum1 += i
sum2 = 0
for i in range(1, 10, 2):
    sum2 -= i
print(sum1+sum2)
# Out:
# 5

# %%
#2b.2
sum = 0
for i in range(2, 11, 2):
    sum += i
for i in range(1, 10, 2):
    sum -= i
print(sum)
# Out:
# 5

# %%
#2c
print(3.14*2*5)
# Out:
# 31.400000000000002

# %%
#2d
print(2*(6+9))
# Out:
# 30

# %%
#3 you did not write "and its area is xxx cm*cm"
# incomplete string in print method.
perimeter = (18+13)*2
area = 2*(6+9)
print("The perimeter of this rectangle is " + str(perimeter) + " and its area is " + str(area) + ".")
# Out:
# The perimeter of this rectangle is 62 and its area is 30.

# %%
#4 not finished
# you are not asked to write codes to answer this question, but to use your own
# words to express your idea.

sum1 = 0
for i in range(1, 101):
    sum1 += i
sum2 = 0
for i in range(100, 10001):
# Out:
#   File "<ipython-input-13-cc11a119e6a5>", line 9
#     for i in range(100, 10001):
#                                ^
# SyntaxError: unexpected EOF while parsing
