# %% [markdown]
# ## 备选题目

# %% [markdown]
# 5. (Optional) You might have noticed that it's very hard to hit the number generated by computer just by one guess in the number guess game. But if you are given 10 chances, you can definitely tell the number, because computer-generated integers are between 0 and 9, and there are only 10 possibilities in total. But there **IS** a way to guarantee that in every game the number will be hit by trying less than 10 times. Do you know how that can be done? How many guesses does it take at most to hit the integer randomly generated between 0 and 9?
#
#    （可选作）你可能注意到了几乎很少能够猜一次就猜对计算机随机生成的0-9之间的一个数。但是如果给你10次机会来猜，你一定可以猜出这个数字，因为计算机生成的整数在0和9之间，一共只有10种可能性。但是**存在一种**方法不需要猜10次就能保证每一局都能猜对。你知道这个方法是怎么做到的吗？它最多需要猜几次就能猜对？

# %%
# Write your answer or thinking here 在这里写下你的答案或这思考
# This question will not be graded, 此题不计分

# %% [markdown]
# 2枚骰子同时掷出，把两枚骰子的点数加在一起，得到一个数。投掷1000次，记住每次得到的数，并且统计得到各个数的次数。把他们打印出来。

# %% [markdown]
# 3. 模拟打麻将掷色子决定起牌位置
